# %%
# Importing neccessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
emp_data = pd.read_csv("/content/Attrition data.csv")
pd.set_option("display.max_columns", None)
emp_data
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
emp_data.shape
# Out:
# (4410, 29)

# %%
emp_data.tail(3)
# Out:
#       EmployeeID  Age Attrition BusinessTravel              Department  \
# 4407        4408   25        No  Travel_Rarely  Research & Development
# 4408        4409   42        No  Travel_Rarely                   Sales
# 4409        4410   40        No  Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount Gender  \
# 4407                25          2  Life Sciences              1   Male
# 4408                18          2        Medical              1   Male
# 4409                28          3        Medical              1   Male
#
#       JobLevel                JobRole MaritalStatus  MonthlyIncome  \
# 4407         2        Sales Executive       Married          37020
# 4408         1  Laboratory Technician      Divorced          23980
# 4409         2  Laboratory Technician      Divorced          54680
#
#       NumCompaniesWorked Over18  PercentSalaryHike  StandardHours  \
# ...

# %%
emp_data.sample(3)
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 2468        2469   38        No  Travel_Frequently  Research & Development
# 3187        3188   26        No      Travel_Rarely  Research & Development
# 3867        3868   43        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  Gender  \
# 2468                28          3        Medical              1    Male
# 3187                 7          2  Life Sciences              1    Male
# 3867                 2          4  Life Sciences              1  Female
#
#       JobLevel                    JobRole MaritalStatus  MonthlyIncome  \
# 2468         1  Healthcare Representative       Married          29790
# 3187         1     Manufacturing Director       Married          54540
# 3867         1         Research Scientist       Married          24220
#
#       NumCompaniesWorked Over18  PercentSalaryHike  StandardHours  \
# ...

# %% [markdown]
# # EmployeeID: Unique identifier for each employee.
# Age: Age of the employee.
# Attrition: Whether the employee has left the company (attrition could be binary: Yes/No).
# BusinessTravel: Frequency of business travel.
# Department: Department in which the employee works.
# DistanceFromHome: Distance of employee's home from the workplace.
# Education: Level of education attained by the employee.
# EducationField: Field of education of the employee.
# EmployeeCount: Number of employees (might be constant if this is just a count).
# Gender: Gender of the employee.
# JobLevel: Level of the employee's job.
# JobRole: Role or position of the employee within the company.
# MaritalStatus: Marital status of the employee.
# MonthlyIncome: Monthly income of the employee.
# NumCompaniesWorked: Number of companies the employee has worked for.
# Over18: Whether the employee is over 18 years old (could be binary: Yes/No).
# PercentSalaryHike: Percentage increase in salary.
# StandardHours: Standard number of working hours (usually 40 hours per week).
# StockOptionLevel: Level of stock options offered to the employee.
# TotalWorkingYears: Total number of years the employee has worked.
# TrainingTimesLastYear: Number of training sessions attended by the employee in the last year.
# YearsAtCompany: Number of years the employee has been with the company.
# YearsSinceLastPromotion: Number of years since the employee's last promotion.
# YearsWithCurrManager: Number of years the employee has been with their current manager.
# EnvironmentSatisfaction: Satisfaction level with the work environment.
# JobSatisfaction: Satisfaction level with the job.
# WorkLifeBalance: Balance between work and personal life.
# JobInvolvement: Level of involvement in the job.
# PerformanceRating: Performance rating of the employee.
# Salary: Salary of the employee (might be redundant with MonthlyIncome).
# Age_group: Grouping of employees based on age.

# %%
emp_data.isnull().sum()
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %%
emp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   Age                      4410 non-null   int64
#  2   Attrition                4410 non-null   object
#  3   BusinessTravel           4410 non-null   object
#  4   Department               4410 non-null   object
#  5   DistanceFromHome         4410 non-null   int64
#  6   Education                4410 non-null   int64
#  7   EducationField           4410 non-null   object
#  8   EmployeeCount            4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
# checking value count
s = emp_data['NumCompaniesWorked'].value_counts()
s
# Out:
# NumCompaniesWorked
# 1.0    1558
# 0.0     586
# 3.0     474
# 2.0     438
# 4.0     415
# 7.0     222
# 6.0     208
# 5.0     187
# 9.0     156
# 8.0     147
# Name: count, dtype: int64

# %%
# percentage of null value
emp_data['NumCompaniesWorked'].isnull().sum()/emp_data['NumCompaniesWorked'].count()*100
# Out:
# 0.43270325666135273

# %%
emp_data = emp_data.fillna({'NumCompaniesWorked' : s.values[0]})
emp_data.isnull().sum()
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked          0
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %%
emp_data['JobSatisfaction'].unique()
# Out:
# array([ 4.,  2.,  1.,  3., nan])

# %%
emp_data['EnvironmentSatisfaction'] = emp_data['EnvironmentSatisfaction'].fillna(0).astype(int)

# %%
emp_data['EnvironmentSatisfaction'].unique()
# Out:
# array([3, 2, 4, 1, 0])

# %%
emp_data['WorkLifeBalance'] = emp_data['WorkLifeBalance'].fillna(0).astype(int)

# %%
emp_data.isnull().sum()
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked          0
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction     0
# JobSatisfaction            20
# WorkLifeBalance             0
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %%
emp_data.head(3)
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  \
# 0                 6          2  Life Sciences              1  Female
# 1                10          1  Life Sciences              1  Female
# 2                17          4          Other              1    Male
#
#    JobLevel                    JobRole MaritalStatus  MonthlyIncome  \
# 0         1  Healthcare Representative       Married         131160
# 1         1         Research Scientist        Single          41890
# 2         4            Sales Executive       Married         193280
#
#    NumCompaniesWorked Over18  PercentSalaryHike  StandardHours  \
# ...

# %%
marital_status_count = emp_data['MaritalStatus'].value_counts()
marital_status_count
# Out:
# MaritalStatus
# Married     2019
# Single      1410
# Divorced     981
# Name: count, dtype: int64

# %%
att_value_counts = emp_data['Attrition'].value_counts()
att_value_counts
# Out:
# Attrition
# No     3699
# Yes     711
# Name: count, dtype: int64

# %%
travel_count = emp_data['BusinessTravel'].value_counts()
travel_count
# Out:
# BusinessTravel
# Travel_Rarely        3129
# Travel_Frequently     831
# Non-Travel            450
# Name: count, dtype: int64

# %%
gender_count = emp_data['Gender'].value_counts()
gender_count
# Out:
# Gender
# Male      2646
# Female    1764
# Name: count, dtype: int64

# %%
jobrole_count = emp_data['JobRole'].value_counts()
jobrole_count
# Out:
# JobRole
# Sales Executive              978
# Research Scientist           876
# Laboratory Technician        777
# Manufacturing Director       435
# Healthcare Representative    393
# Manager                      306
# Sales Representative         249
# Research Director            240
# Human Resources              156
# Name: count, dtype: int64

# %%
# checking duplicate values in the dataframe
emp_data.duplicated().sum()
# Out:
# 0

# %%
# performing describe function on the numerical features
emp_data.describe().T
# Out:
#                           count          mean           std      min  \
# EmployeeID               4410.0   2205.500000   1273.201673      1.0
# Age                      4410.0     36.923810      9.133301     18.0
# DistanceFromHome         4410.0      9.192517      8.105026      1.0
# Education                4410.0      2.912925      1.023933      1.0
# EmployeeCount            4410.0      1.000000      0.000000      1.0
# JobLevel                 4410.0      2.063946      1.106689      1.0
# MonthlyIncome            4410.0  65029.312925  47068.888559  10090.0
# NumCompaniesWorked       4410.0      9.395692    101.909537      0.0
# PercentSalaryHike        4410.0     15.209524      3.659108     11.0
# StandardHours            4410.0      8.000000      0.000000      8.0
# StockOptionLevel         4410.0      0.793878      0.851883      0.0
# TotalWorkingYears        4401.0     11.279936      7.782222      0.0
# TrainingTimesLastYear    4410.0      2.799320      1.288978      0.0
# ...

# %%
def Salary(MonthlyIncome):
  if MonthlyIncome <= 30000:
    return 'Low'
  elif MonthlyIncome <= 80000:
    return 'Medium'
  elif MonthlyIncome <= 200000:
    return 'High'
  else:
    return 'NA'

emp_data['Salary'] = emp_data['MonthlyIncome'].apply(Salary)
emp_data
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
pd.crosstab(emp_data.Salary,emp_data.Attrition)
# Out:
# Attrition    No  Yes
# Salary
# High        987  156
# Low         978  207
# Medium     1734  348

# %%
pd.crosstab(emp_data.Salary,emp_data.Attrition).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Salary'>

# %%
def Age_group(Age):
    if Age <= 30:
        return '18-30'
    elif Age <= 40:
        return '31-40'
    else:
        return '41-60'


emp_data['Age_group'] = emp_data['Age'].apply(Age_group)
emp_data
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
emp_data['PerformanceRating'].unique()
# Out:
# array([3, 4])

# %%
p = emp_data['PerformanceRating'].value_counts()

# %% [markdown]
# # Dropping Useless Features

# %%
drop_features = emp_data.drop(['JobLevel','Education','EmployeeCount','Over18','EducationField','StockOptionLevel'], axis = 1)
drop_features
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %% [markdown]
# # Distribution of Employees Attrition

# %%
explode = (0,0.1)
lables = 'Attrition NO', 'Attrition YES'
emp_data['Attrition'] .astype(str).value_counts().plot(kind='pie',figsize=(8,4),
                                                       autopct = '%1.1f%%',
                                                       startangle = 90,
                                                       shadow = True,
                                                       explode = explode,
                                                       colors = ['rosybrown','gray'],
                                                       labels = None)
plt.title('Distribution of employee Attrition in the company')
plt.axis('equal')
plt.legend(labels = lables, loc='upper left')
plt.show()

# %% [markdown]
# ### We can see in the company, the distribution of employee attrition is as follows: 16% of employees have left the company (attrition Yes), while 84% of employees have remained with the company (attrition No).

# %% [markdown]
# **Analysis of the Rating  Features :
# 1. EnvironmentSatisfaction
# 2. JobSatisfaction
# 3. JobInvolvement
#
# [link text](https:// [link text](https://))**

# %%
fig = plt.figure(figsize = (12,8))

ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)

labels = 'Low', 'Medium', 'High', 'Very High' # We can also specified labels directly in the plot() function, when creating the pie chart.

emp_data['EnvironmentSatisfaction'].value_counts().plot(kind = 'pie',
                                                       autopct = '%1.1f%%',
                                                       startangle = 90,
                                                       shadow = True,
                                                       colors = sns.color_palette('Set2'),
                                                       labels = None, ax = ax1)
ax1.set_title('Rating of Environment Satisfaction by employees')
fig.legend(labels = labels, loc = 'center')

emp_data['JobSatisfaction'].value_counts().plot(kind = 'pie',
                                              autopct = '%1.1f%%',
                                              startangle = 90,
                                              shadow = True,
                                              colors = sns.color_palette('Set2'),
                                              labels = None, ax = ax2)
ax2.set_title('Rating of Job satisfaction by employees')

emp_data['JobInvolvement'].value_counts().plot(kind = 'pie',
                                              autopct = '%1.1f%%',
                                              startangle = 90,
                                              shadow = True,
                                              colors = sns.color_palette('Set2'),
                                              labels = None,ax = ax3)
ax3.set_title('Rating of Job Involvement by employees')
plt.show()

# %% [markdown]
# ## So, We can see the above Subplot, indicates significant employee dissatisfaction within the company: almost 60% are not satisfied with the work environment, 60% are not satisfied with their job, and 84% are not getting job involvement.

# %% [markdown]
# # Analysis of Work-life Balance and Performance Rating

# %%
fig2 = plt.figure()

ax4 = fig2.add_subplot(121)
ax5 = fig2.add_subplot(122)

labels_list1 = 'Bad', 'Good', 'Best', 'Better'
labels_list2 = 'Bad', 'Good', 'Excellent', 'Outstanding'

emp_data['WorkLifeBalance'].astype(str).value_counts().plot(kind = 'pie',
                                              figsize = (10,5),
                                              autopct = '%1.1f%%',
                                              startangle = 90,
                                              shadow = True,
                                              colors = sns.color_palette('Set2'),
                                              labels = None, ax = ax4)
ax4.set_title('Rating of Work-Life Balance by employees')
ax4.legend(labels = labels_list1, loc = 'upper right')

emp_data['PerformanceRating'].astype(str).value_counts().plot(kind = 'pie',
                                              figsize = (10,5),
                                              autopct = '%1.1f%%',
                                              startangle = 90,
                                              shadow = True,
                                              colors = sns.color_palette('Set2'),
                                              labels = None,ax = ax5)
ax5.set_title('Performance Rating by employees')
ax5.legend(labels =labels_list2, loc = 'upper right')
plt.show()

# %% [markdown]
# ### From the above Pie chart, we can see that:
# ### 60% of employees rate their work-life balance as Bad.
# ### 85% of employees rate their performance as Bad.
#
# ### Enhance Work-Life Balance: Implement policies that support flexible working hours, remote work options, and encourage taking regular breaks. Improving work-life balance can help reduce burnout and increase employee satisfaction.
#
# ### Performance Concerns: Provide clear performance expectations and regular feedback. Offer training and development programs to help employees improve their skills and performance. Recognize and reward high performers to motivate others.

# %% [markdown]
# # Analysis of Busniness Travel Feature

# %%
grouped = emp_data.groupby('BusinessTravel')['Attrition'].value_counts(normalize = False).unstack()
grouped.plot(kind = 'bar',alpha = 0.7, stacked = 'False') #alpha parameter takes between 0 to 1,
plt.title('Busniness Travel Vs Attrition')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# ### From the above plot, it is clear that employees who travel rarely have higher attrition rates compared to those who travel frequently. To reduce the attrition rate, it is recommended to assign travel duties based on employees' business interests and preferences. This approach can help improve job satisfaction.

# %%
emp_data.columns
# Out:
# Index(['EmployeeID', 'Age', 'Attrition', 'BusinessTravel', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'Gender', 'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance',
#        'JobInvolvement', 'PerformanceRating', 'Salary', 'Age_group'],
#       dtype='object')

# %%
new_df = emp_data[['Attrition','YearsAtCompany','YearsWithCurrManager','YearsSinceLastPromotion','PercentSalaryHike','TotalWorkingYears']]
new_df.head()
# Out:
#   Attrition  YearsAtCompany  YearsWithCurrManager  YearsSinceLastPromotion  \
# 0        No               1                     0                        0
# 1       Yes               5                     4                        1
# 2        No               5                     3                        0
# 3        No               8                     5                        7
# 4        No               6                     4                        0
#
#    PercentSalaryHike  TotalWorkingYears
# 0                 11                1.0
# 1                 23                6.0
# 2                 15                5.0
# 3                 11               13.0
# 4                 12                9.0

# %%
year_at_co = emp_data.groupby('YearsAtCompany')['Attrition'].value_counts(normalize = False).unstack()
plt.figure(figsize = (8,6))
year_at_co.plot(kind = 'bar', stacked = 'False', color = ['#007acc', '#00cc99'])
plt.title('Years at company of Employees')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# ### According to the above data, most of the newely arrived employees are leaving their jobs. To reduce the attrition rate among freshers, it is essential to implement strong policies and support systems specifically tailored for new employees. This could include structured onboarding programs, mentorship opportunities, clear career development paths, and regular feedback sessions to help freshers integrate better and feel more valued within the company.

# %%
ycm = emp_data.groupby('YearsWithCurrManager')['Attrition'].value_counts(normalize = False).unstack()
plt.figure(figsize = (10,6))
ycm.plot(kind = 'bar', stacked = 'False', color = ['green', '#ff9900'])
plt.title('Years with Manager of Employees')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# ### Bssed on the above data, it is clear that starting of relation with their manager are not so good, it is important that the manager communicate with the employees and trying to understand them.

# %% [markdown]
# ## Analysis of based on Last Promotion and Percantage Hike

# %%
#Groups dataframe with sFeatures in
ylp = emp_data.groupby('YearsSinceLastPromotion')['Attrition'].value_counts(normalize = False).unstack()
psh = emp_data.groupby('PercentSalaryHike')['Attrition'].value_counts(normalize = False).unstack()

#Create Figure
fig = plt.figure(figsize = (15,5))
ax0 = fig.add_subplot(121)
ax1 = fig.add_subplot(122)

#Subplot 1: Bar Plot
ylp.plot(kind = 'bar', stacked = 'False', color = ['green', 'orange'], ax = ax0)
ax0.set_title('Last promotion')
ax0.set_ylabel('Number of Employees')
ax0.set_xlabel('Years Since Last Promotion')

#Subplot 2: Line Plot
psh.plot(kind = 'line', stacked = 'False', color = ['green', 'orange'], ax = ax1)
ax1.set_title('Percentage of Hike')
ax1.set_ylabel('Number of Employees')
ax1.set_xlabel('Percentage Salary Hike')

plt.show()

# %%
twy = emp_data.groupby('TotalWorkingYears')['Attrition'].value_counts(normalize = False).unstack()
plt.figure(figsize = (10,6))
twy.plot(kind = 'bar', stacked = 'False', color = ['#007acc', '#00cc99'])
plt.title('Total Working years')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# # Data Manipulation

# %% [markdown]
# # Analysis of Monthly Income wise

# %%
mi = emp_data[emp_data['Attrition'] == 'Yes']['MonthlyIncome']
mi = mi.reset_index()
mi.drop(['index'], axis = 1, inplace = True)

mn = emp_data[emp_data['Attrition']=='No']['MonthlyIncome']
mn = mn.reset_index()
mn.drop(['index'], axis = 1, inplace = True)

mi['mn'] = mn
mi.rename(columns = {'MonthlyIncome' : 'Yes', 'mn': 'No'}, inplace = True)
mi.head(10)
# Out:
#       Yes      No
# 0   41890  131160
# 1   58130  193280
# 2   57620   83210
# 3  103330   23420
# 4   68540   40710
# 5  157870   31430
# 6   23350   20440
# 7   47740  134640
# 8   56730   79910
# 9   42840   33770

# %%
fig = plt.figure(figsize = (10,6))
mi.plot(kind = 'box')
plt.title('Monthly Income vs Attrition')
plt.ylabel('Monthly Income')
plt.show()

# %% [markdown]
# # Analysis of Department wise

# %%
dpt = emp_data[['Department', 'Attrition']]
dpt
# Out:
#                   Department Attrition
# 0                      Sales        No
# 1     Research & Development       Yes
# 2     Research & Development        No
# 3     Research & Development        No
# 4     Research & Development        No
# ...                      ...       ...
# 4405  Research & Development        No
# 4406  Research & Development        No
# 4407  Research & Development        No
# 4408                   Sales        No
# 4409  Research & Development        No
#
# [4410 rows x 2 columns]

# %%
dep_count = emp_data['Department'].value_counts()
dep_count
# Out:
# Department
# Research & Development    2883
# Sales                     1338
# Human Resources            189
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10,5))
# Define a color palette
colors = ['#ff9999', '#66b3ff', '#99ff99']
dpt['Department'].value_counts().plot(kind = 'pie',
                                     autopct = '%1.1f%%',
                                     startangle = 90,
                                     shadow = True,
                                     colors = colors,
                                     labels = None)
plt.title('Department')
plt.axis('equal')
plt.legend(labels = dpt['Department'].unique(), loc='upper left')
plt.show()

# %%
dpt_group = emp_data.groupby('Department')['Attrition'].value_counts(normalize = False).unstack()
dpt_group = dpt_group.T # T means transpose
dpt_group
# Out:
# Department  Human Resources  Research & Development  Sales
# Attrition
# No                      132                    2430   1137
# Yes                      57                     453    201

# %%
labels = ['Sales','Research & Development','Human Resourses']
sizes = [1338,2883,189]
labels_att = ['Yes','No','Yes','No','Yes','No']
sizes_att = [201,1137,453,2430,57,132]
colors = ['#ff6666','#ffcc99','#99ff99']

colors_att = ['#0a0e77','#9e0723','#0a0e77','#9e0723','#0a0e77','#9e0723','#0a0e77','#9e0723']
plt.pie(sizes, autopct = '%1.1f%%', pctdistance = .87, labels = labels, colors = colors, startangle = 90, frame = True)
plt.pie(sizes_att, colors = colors_att,radius = 0.75, startangle = 90)
centre_circle = plt.Circle((0,0),0.5, color = 'black', fc = 'white', linewidth = 0.5)
fig6 = plt.gcf()
fig6.gca().add_artist(centre_circle)

import matplotlib.patches as mpatches

pur = mpatches.Patch(color='#0a0e77', label='Yes')
pin = mpatches.Patch(color='#9e0723', label='No')
plt.legend(handles=[pur,pin], loc = 'upper right')

plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analysis of Marital Status wise

# %%
ms = emp_data[['MaritalStatus','Attrition']]
ms
# Out:
#      MaritalStatus Attrition
# 0          Married        No
# 1           Single       Yes
# 2          Married        No
# 3          Married        No
# 4           Single        No
# ...            ...       ...
# 4405        Single        No
# 4406      Divorced        No
# 4407       Married        No
# 4408      Divorced        No
# 4409      Divorced        No
#
# [4410 rows x 2 columns]

# %%
ms_count = emp_data['MaritalStatus'].value_counts()
ms_count
# Out:
# MaritalStatus
# Married     2019
# Single      1410
# Divorced     981
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10,5))
# Define a color palette
colors = ['#ff6f61', '#6b5b95', '#88b04b']
ms['MaritalStatus'].value_counts().plot(kind='pie',
                                        autopct='%1.1f%%',
                                        startangle=90,
                                        shadow=True,
                                        colors=colors,
                                        labels= None)
plt.axis('equal')
plt.legend(labels = ['Married','Single','Divorced'], loc='upper left')
plt.show()

# %%
ms_grp = ms.groupby('MaritalStatus').value_counts(normalize = False).unstack()
ms_grp = ms_grp.T
ms_grp
# Out:
# MaritalStatus  Divorced  Married  Single
# Attrition
# No                  882     1767    1050
# Yes                  99      252     360

# %%
labels = ['Married','Single','Divorced']
sizes = [219,1410,981]
labels_att = ['Yes','No','Yes','No','Yes','No']
sizes_att = [252,1767,360,1050,99,882]
colors = ['#ff6666','#ffcc99','#99ff99']

colors_att = [ '#FFD700','#40E0D0','#6495ED','#FF4500','#EE82EE','#0a0e77','#9e0723']
plt.pie(sizes, autopct = '%1.1f%%', pctdistance = .87, labels = labels, colors = colors, startangle = 90, frame = True)
plt.pie(sizes_att, colors = colors_att,radius = 0.75, startangle = 90)
centre_circle = plt.Circle((0,0),0.5, color = 'black', fc = 'white', linewidth = 0.5)
fig6 = plt.gcf()
fig6.gca().add_artist(centre_circle)

import matplotlib.patches as mpatches

pur = mpatches.Patch(color='#0a0e77', label='Yes')
pin = mpatches.Patch(color='#9e0723', label='No')
plt.legend(handles=[pur,pin], loc = 'upper right')

plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Completed
